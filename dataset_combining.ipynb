# %%
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load CSV files from Google Drive
csv_file1 = '/content/drive/MyDrive/Revised Links 2.0/state wise macronutrients/state wise macronutrients 2023-24.csv'
csv_file2 = '/content/drive/MyDrive/Revised Links 2.0/state wise micro/state wise micronutrients 2023-24.csv'

df1 = pd.read_csv(csv_file1)
df2 = pd.read_csv(csv_file2)

# Combine the DataFrames
combined_df = pd.concat([df1, df2], axis=1)

# Save the combined DataFrame to a new CSV file if needed
combined_df.to_csv('/content/drive/MyDrive/Revised Links 2.0/combined_file.csv', index=False)

# Display the combined DataFrame
combined_df

from google.colab import files
files.download('/content/drive/MyDrive/Revised Links 2.0/combined_file.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Drop the second 'State' column
df_combineed1 = pd.read_csv('/content/drive/MyDrive/Revised Links 2.0/combined_file (1).csv')
df_combineed1 = df_combineed1.drop(columns=['State1'])

# Save the updated DataFrame to a new CSV file
df_combineed1.to_csv('/content/drive/MyDrive/Revised Links 2.0/combined_file_without_second_state.csv', index=False)

# Download the updated CSV file
files.download('/content/drive/MyDrive/Revised Links 2.0/combined_file_without_second_state.csv')

df_combineed1.head()
# Out:
#                          State Nitrogen - High Nitrogen - Medium  \
# 0                      TRIPURA           0.11%            38.82%
# 1  ANDAMAN AND NICOBAR ISLANDS              0%            27.02%
# 2                          GOA          28.38%            46.91%
# 3                     NAGALAND           6.16%            57.31%
# 4                        BIHAR           0.66%            38.26%
#
#   Nitrogen - Low Phosphorous - High Phosphorous - Medium Phosphorous - Low  \
# 0         61.07%              2.21%               96.81%             0.98%
# 1         72.98%                 0%               27.77%            72.23%
# 2         24.71%             23.46%               31.71%            44.83%
# 3         36.52%             13.01%               63.67%            23.33%
# 4         61.08%             20.71%               77.07%             2.22%
#
#   Potassium - High Potassium - Medium Potassium - Low  ... Boron - Sufficient  \
# ...
